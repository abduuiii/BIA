# %%
print("hello")
# Out:
# hello

# %%
name="abduuii"
print(name)
print(f"my name is {name}")
# Out:
# abduuii
# my name is abduuii

# %%
sentence="python is easy and python is fun"
print(sentence)
index=sentence.find("y")
print(index)
replaced_sentence=sentence.replace("python","javascript")
print("replaced sentence:",replaced_sentence)
#count_is=sentence.count("is")
#print("count of 'is': ",count_is)
text="hello,world!"
starts_with_hello = text.startswith("hello")
print("starts with 'hello':",starts_with_hello)
# Out:
# python is easy and python is fun
# 1
# replaced sentence: javascript is easy and javascript is fun
# starts with 'hello': True

# %%
sentence="python is easy and fun"
word = sentence.split()
print(word)
joined_sentence="_".join(word)
print("joined sentence:",joined_sentence)
# Out:
# ['python', 'is', 'easy', 'and', 'fun']
# joined sentence: python_is_easy_and_fun

# %%
x=10
if x>5:
    print("x is greater than 5")
elif x==5:
    print("x is equal to 5")
else:
    print("x is less than 5")
# Out:
# x is greater than 5

# %%
x=10
y=5
if x>5:
    print("x is greater than 5")
    if y<10:
       print("y is less than 10")
    else:
        print("y is greater than or equal to 10")
else:
    print("y is greater than or equal to 10")
# Out:
# x is greater than 5
# y is less than 10

# %%
name=input("enter your name:")
print(f"your name is :{name}")
# Out:
# your name is :abduuii

# %%
count=3
while count<=5:
    print("count:",count)
    count=count+1
print("loop ended.")
# Out:
# count: 3
# count: 4
# count: 5
# loop ended.

# %%
fruits=["apple","banana","cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
for i in range(5):
    if i==2:
        break
    print(i)
# Out:
# 0
# 1

# %%
for i in range(5):
    if i==2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
numbers=[1,2,3,4,5]
sum=0
for i in numbers:
    sum=sum+i
print(sum)
# Out:
# 15

# %%
def sum_myown(list_numbers):
    sum=0
    for i in list_numbers:
        sum=sum+i
    print(sum)

# %%
def greet(name):
    print(f"hello, {name}, how are you today?")
greet("abduuii")
# Out:
# hello, abduuii, how are you today?

# %%
def greet(name,greeting="Hello"):
    """Greets a person with a customizable greeting."""
    print(f"{greeting},{name}")
greet(name="alice")
greet(name="das",greeting="Hi")
greet("charlie,""shinu")
# Out:
# Hello,alice
# Hi,das
# Hello,charlie,shinu

# %%
global_var=10
def my_function():
    local_var=5
    print(global_var)
    print(local_var)
my_function()
print(global_var)
print(local_var)
# Out:
# 10
# 5
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 8
#       4     print(global_var)
#       5     print(local_var)
#       6 my_function()
#       7 print(global_var)
# ----> 8 print(local_var)
#
# NameError: name 'local_var' is not defined

# %%
try:
    result=10/0
except ZeroDivisionError:
    print("error:division by zero.")
finally:
    print("this will always execute")
# Out:
# error:division by zero.
# this will always execute
