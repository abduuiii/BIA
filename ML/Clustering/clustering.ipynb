# %%
# Kmean clustering implementation in Python
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
 
# train test split
from sklearn.model_selection import train_test_split
 
# Load dataset
data = pd.read_csv(r'C:\Users\abdul\Documents\BIA\ML\Dataset\customer_segmentation.csv')
import warnings
warnings.filterwarnings('ignore')

# %%
data.head(10)
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
# 5  461319    Male          Yes   56        No         Artist              0.0
# 6  460156    Male           No   32       Yes     Healthcare              1.0
# 7  464347  Female           No   33       Yes     Healthcare              1.0
# 8  465015  Female          Yes   61       Yes       Engineer              0.0
# 9  465176  Female          Yes   55       Yes         Artist              1.0
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# ...

# %%
# drop the ID column
data = data.drop(['ID','Var_1','Segmentation'], axis=1)
data.head()
# Out:
#    Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0    Male           No   22        No     Healthcare              1.0
# 1  Female          Yes   38       Yes       Engineer              NaN
# 2  Female          Yes   67       Yes       Engineer              1.0
# 3    Male          Yes   67       Yes         Lawyer              0.0
# 4  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size
# 0            Low          4.0
# 1        Average          3.0
# 2            Low          1.0
# 3           High          2.0
# 4           High          6.0

# %%
data.shape
# Out:
# (10695, 8)

# %%
data.isnull().sum()
# Out:
# Gender                0
# Ever_Married        190
# Age                   0
# Graduated           102
# Profession          162
# Work_Experience    1098
# Spending_Score        0
# Family_Size         448
# dtype: int64

# %%
# identify categorical columns and numerical columns
categorical_cols = data.select_dtypes(include=['object']).columns
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns
print("Categorical Columns:", categorical_cols)
print("Numerical Columns:", numerical_cols)
# Out:
# Categorical Columns: Index(['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score'], dtype='str')
# Numerical Columns: Index(['Age', 'Work_Experience', 'Family_Size'], dtype='str')

# %%
# missing value imputation for numerical columns
for col in numerical_cols:
    data[col] = data[col].fillna(data[col].median())

# %%
# missing value imputation for categorical columns
for col in categorical_cols:
    if col=="Profession":
        data[col] = data[col].fillna("Others")
    else:
        data[col] = data[col].fillna(data[col].mode()[0])
 
# functions def(df,column_name,customName)

# %%
data.isnull().sum()
# Out:
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# dtype: int64

# %%
data.head()
# Out:
#    Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0    Male           No   22        No     Healthcare              1.0
# 1  Female          Yes   38       Yes       Engineer              1.0
# 2  Female          Yes   67       Yes       Engineer              1.0
# 3    Male          Yes   67       Yes         Lawyer              0.0
# 4  Female          Yes   40       Yes  Entertainment              1.0
#
#   Spending_Score  Family_Size
# 0            Low          4.0
# 1        Average          3.0
# 2            Low          1.0
# 3           High          2.0
# 4           High          6.0

# %% [markdown]
# #### Encoding

# %%
data['Ever_Married'] = data['Ever_Married'].map({"Yes":1,"No":0})
data['Graduated'] = data['Graduated'].map({"Yes":1,"No":0})
data.head()
# Out:
#    Gender  Ever_Married  Age  Graduated     Profession  Work_Experience  \
# 0    Male             0   22          0     Healthcare              1.0
# 1  Female             1   38          1       Engineer              1.0
# 2  Female             1   67          1       Engineer              1.0
# 3    Male             1   67          1         Lawyer              0.0
# 4  Female             1   40          1  Entertainment              1.0
#
#   Spending_Score  Family_Size
# 0            Low          4.0
# 1        Average          3.0
# 2            Low          1.0
# 3           High          2.0
# 4           High          6.0

# %%
data=pd.get_dummies(
    data,
    columns=["Gender"],
    dtype=int
)

# %%
pr = data['Profession'].value_counts()
pr_dict = pr.rank(method="dense", ascending=True).astype(int).to_dict()
data['Profession'] = data['Profession'].map(pr_dict)
 
sc = data['Spending_Score'].value_counts()
sc_dict = sc.rank(method="dense", ascending=True).astype(int).to_dict()
data['Spending_Score'] = data['Spending_Score'].map(sc_dict)

# %%
data.head(10)
# Out:
#    Ever_Married  Age  Graduated  Profession  Work_Experience  Spending_Score  \
# 0             0   22          0           9              1.0               3
# 1             1   38          1           7              1.0               2
# 2             1   67          1           7              1.0               3
# 3             1   67          1           5              0.0               1
# 4             1   40          1           8              1.0               1
# 5             1   56          0          10              0.0               2
# 6             0   32          1           9              1.0               3
# 7             0   33          1           9              1.0               3
# 8             1   61          1           7              0.0               3
# 9             1   55          1          10              1.0               2
#
#    Family_Size  Gender_Female  Gender_Male
# 0          4.0              0            1
# ...

# %%
# transform data 
for col in numerical_cols:
    scaler = StandardScaler()
    data[col] = scaler.fit_transform(data[[col]])

# %%
data.head()
# Out:
#    Ever_Married       Age  Graduated  Profession  Work_Experience  \
# 0             0 -1.282499          0           9        -0.447327
# 1             1 -0.328606          1           7        -0.447327
# 2             1  1.400325          1           7        -0.447327
# 3             1  1.400325          1           5        -0.755089
# 4             1 -0.209369          1           8        -0.447327
#
#    Spending_Score  Family_Size  Gender_Female  Gender_Male
# 0               3     0.764161              0            1
# 1               2     0.099335              1            0
# 2               3    -1.230315              1            0
# 3               1    -0.565490              0            1
# 4               1     2.093811              1            0

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
kmeans.labels_
# Out:
# array([3, 2, 2, ..., 2, 4, 0], shape=(10695,), dtype=int32)

# %%
# Elbow method to find the best K
inertia = [] # within cluster sum of squares
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data)
    inertia.append(kmeans.inertia_)

# %%
# plotting the inertia
import matplotlib.pyplot as plt
 
plt.figure(figsize=(5, 3))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()
